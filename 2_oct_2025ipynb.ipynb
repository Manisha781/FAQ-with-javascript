# %% [markdown]
# <a href="https://colab.research.google.com/github/Manisha781/FAQ-with-javascript/blob/main/2_oct_2025ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter a number:"))
if num>=0:
     print("this is postive number:")
else:
      print("this is negative numer:")
# Out:
# enter a number:-1
# this is negative numer:

# %%
temperature=int(input("enter a number:"))
if temperature>30:
     print("its high temperature:")
else:
      print("its low temperature:")
# Out:
# enter a number:67
# its high temperature:

# %%
num=int(input("enter a number:"))
if num%5==0:
     print("disisible by 5:")
else:
      print("Not disisible by 5:")
# Out:
# enter a number:15
# disisible by 5:

# %%
masks=int(input("enter a number:"))
if masks>=50:
     print("you are passed:")
else:
      print("you are not passed:")
# Out:
# enter a number:45
# you are not passed:

# %%
num=int(input("enter a number:"))
if num>0:
     print("this is postive number:")
elif num==0:
     print("this is zero:")
else:
      print("this is negative numer:")
# Out:
# enter a number:-9
# this is negative numer:

# %%
num=int(input("enter a number:"))
if num>0:
     print("this is postive number:")
if num==0:
     print("this is zero:")
else:
      print("this is negative number:")
# Out:
# enter a number:8
# this is postive number:
# this is negative number:
